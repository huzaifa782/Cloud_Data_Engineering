# %% [markdown]
# # Recap

# %%
pop = ['2.5billion', '3billion', '4billion', '4.5billion']
countries = ['pakistan', 'india', 'netherland', 'afghanistan']
alb = countries.index('india')
alb
# Out:
# 1

# %%
pop = ['2.5billion', '3billion', '4billion', '4.5billion']
countries = ['pakistan', 'india', 'netherland', 'afghanistan']
alb = countries.index('afghanistan')
alb
# Out:
# 3

# %%
pop = ['2.5billion', '3billion', '4billion', '4.5billion']
countries = ['pakistan', 'india', 'netherland', 'afghanistan']
countries[3]
# Out:
# 'afghanistan'

# %%
pop = ['2.5billion', '3billion', '4billion', '4.5billion']
countries = ['pakistan', 'india', 'netherland', 'afghanistan']
pop[2]
# Out:
# '4billion'

# %%
pop = ['2.5billion', '3billion', '4billion', '4.5billion']
countries = ['pakistan', 'india', 'netherland', 'afghanistan']
pop[countries.index('afghanistan')]
# Out:
# '4.5billion'

# %%
pop = ['2.5billion', '3billion', '4billion', '4.5billion']
countries = ['pakistan', 'india', 'netherland', 'afghanistan']
countries[pop.index('3billion')]
# Out:
# 'india'

# %% [markdown]
# # Dictionaries

# %%
world = {"Pakistan" : "22Billion", "India" : "102Billion", "Afghanistan" : "10Billion"}
world
# Out:
# {'Pakistan': '22Billion', 'India': '102Billion', 'Afghanistan': '10Billion'}

# %%
world["Pakistan"]
# Out:
# '22Billion'

# %%
world = {"Pakistan" : "22Billion", "India" : "102Billion", "Afghanistan" : "10Billion", "India" : "104Billion" }
world
# Out:
# {'Pakistan': '22Billion', 'India': '104Billion', 'Afghanistan': '10Billion'}

# %%
world["Iran"] = "4Billion"

# %%
world
# Out:
# {'Pakistan': '22Billion',
#  'India': '104Billion',
#  'Afghanistan': '10Billion',
#  'Iran': '4Billion'}

# %%
del world["Iran"]

# %%
world
# Out:
# {'Pakistan': '22Billion', 'India': '104Billion', 'Afghanistan': '10Billion'}

# %%
world.pop("Pakistan")
# Out:
# '22Billion'

# %%
world
# Out:
# {'India': '104Billion', 'Afghanistan': '10Billion'}

# %%
world["Pakistan"] = "22Billion"

# %%
world
# Out:
# {'India': '104Billion', 'Afghanistan': '10Billion', 'Pakistan': '22Billion'}

# %%
{"Names" : ["Huzaifa"  "Mehmood"]}
# Out:
# {'Names': ['HuzaifaMehmood']}

# %%
"Pakistan" in world
# Out:
# True

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 1.1 MB/s eta 0:00:11
#    ---------------------------------------- 0.1/11.5 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.5 MB 1.3 MB/s eta 0:00:09
#     --------------------------------------- 0.2/11.5 MB 807.1 kB/s eta 0:00:15
#     --------------------------------------- 0.2/11.5 MB 778.2 kB/s eta 0:00:15
#     --------------------------------------- 0.2/11.5 MB 778.2 kB/s eta 0:00:15
#     --------------------------------------- 0.3/11.5 MB 853.3 kB/s eta 0:00:14
#     --------------------------------------- 0.3/11.5 MB 853.3 kB/s eta 0:00:14
# ...

# %%
import pandas as pd

# %%
bricks = {"country": ['Brazil', 'Russia', 'India', 'China', 'South Africa'],
         "capital": ['Brazilia', 'Moscow', 'New Delhi', 'Beijing', 'Pretoria'],
         "area": [8.516, 17.100, 3.286, 9.597, 1.221],
         "population": [200.40, 143.50, 1252.00, 1357.00, 52.98]}

# %%
df = pd.DataFrame(bricks)
df
# Out:
#         country    capital    area  population
# 0        Brazil   Brazilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
df.index = ["BR", "RU", "IN", "CH", "SF"]

# %%
df
# Out:
#          country    capital    area  population
# BR        Brazil   Brazilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SF  South Africa   Pretoria   1.221       52.98

# %%
import pandas as pd
bricks_csv = pd.read_csv('./gapminder.csv')
bricks_csv.head(6
               )
# Out:
#    Unnamed: 0      country  year  population      cont  life_exp       gdp_cap
# 0          11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 1          23      Albania  2007     3600523    Europe    76.423   5937.029526
# 2          35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 3          47       Angola  2007    12420476    Africa    42.731   4797.231267
# 4          59    Argentina  2007    40301927  Americas    75.320  12779.379640
# 5          71    Australia  2007    20434176   Oceania    81.235  34435.367440

# %%
bricks_csv.tail
# Out:
# <bound method NDFrame.tail of      Unnamed: 0             country  year  population      cont  life_exp  \
# 0            11         Afghanistan  2007    31889923      Asia    43.828
# 1            23             Albania  2007     3600523    Europe    76.423
# 2            35             Algeria  2007    33333216    Africa    72.301
# 3            47              Angola  2007    12420476    Africa    42.731
# 4            59           Argentina  2007    40301927  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137        1655             Vietnam  2007    85262356      Asia    74.249
# 138        1667  West Bank and Gaza  2007     4018332      Asia    73.422
# 139        1679         Yemen, Rep.  2007    22211743      Asia    62.698
# 140        1691              Zambia  2007    11746035    Africa    42.384
# 141        1703            Zimbabwe  2007    12311143    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# ...

# %%
bricks_csv = pd.read_csv('./gapminder.csv', index_col=0)
bricks_csv.head()
# Out:
#         country  year  population      cont  life_exp       gdp_cap
# 11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23      Albania  2007     3600523    Europe    76.423   5937.029526
# 35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 47       Angola  2007    12420476    Africa    42.731   4797.231267
# 59    Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
country = bricks_csv['country']
country
# Out:
# 11             Afghanistan
# 23                 Albania
# 35                 Algeria
# 47                  Angola
# 59               Argentina
#                ...
# 1655               Vietnam
# 1667    West Bank and Gaza
# 1679           Yemen, Rep.
# 1691                Zambia
# 1703              Zimbabwe
# Name: country, Length: 142, dtype: object

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
country = bricks_csv[['country']]
country
# Out:
#                  country
# 11           Afghanistan
# 23               Albania
# 35               Algeria
# 47                Angola
# 59             Argentina
# ...                  ...
# 1655             Vietnam
# 1667  West Bank and Gaza
# 1679         Yemen, Rep.
# 1691              Zambia
# 1703            Zimbabwe
#
# [142 rows x 1 columns]

# %%
type(country)
# Out:
# pandas.core.frame.DataFrame

# %%
bricks_csv[['country','year']]
# Out:
#                  country  year
# 11           Afghanistan  2007
# 23               Albania  2007
# 35               Algeria  2007
# 47                Angola  2007
# 59             Argentina  2007
# ...                  ...   ...
# 1655             Vietnam  2007
# 1667  West Bank and Gaza  2007
# 1679         Yemen, Rep.  2007
# 1691              Zambia  2007
# 1703            Zimbabwe  2007
#
# [142 rows x 2 columns]

# %%
bricks_csv[:]
# Out:
#                  country  year  population      cont  life_exp       gdp_cap
# 11           Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23               Albania  2007     3600523    Europe    76.423   5937.029526
# 35               Algeria  2007    33333216    Africa    72.301   6223.367465
# 47                Angola  2007    12420476    Africa    42.731   4797.231267
# 59             Argentina  2007    40301927  Americas    75.320  12779.379640
# ...                  ...   ...         ...       ...       ...           ...
# 1655             Vietnam  2007    85262356      Asia    74.249   2441.576404
# 1667  West Bank and Gaza  2007     4018332      Asia    73.422   3025.349798
# 1679         Yemen, Rep.  2007    22211743      Asia    62.698   2280.769906
# 1691              Zambia  2007    11746035    Africa    42.384   1271.211593
# 1703            Zimbabwe  2007    12311143    Africa    43.487    469.709298
#
# [142 rows x 6 columns]

# %%
bricks_csv[:5]
# Out:
#         country  year  population      cont  life_exp       gdp_cap
# 11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23      Albania  2007     3600523    Europe    76.423   5937.029526
# 35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 47       Angola  2007    12420476    Africa    42.731   4797.231267
# 59    Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
bricks_csv[3:7]
# Out:
#       country  year  population      cont  life_exp       gdp_cap
# 47     Angola  2007    12420476    Africa    42.731   4797.231267
# 59  Argentina  2007    40301927  Americas    75.320  12779.379640
# 71  Australia  2007    20434176   Oceania    81.235  34435.367440
# 83    Austria  2007     8199783    Europe    79.829  36126.492700

# %%
bricks_csv[2:5]
# Out:
#       country  year  population      cont  life_exp       gdp_cap
# 35    Algeria  2007    33333216    Africa    72.301   6223.367465
# 47     Angola  2007    12420476    Africa    42.731   4797.231267
# 59  Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
bricks_csv.loc[35]
# Out:
# country           Algeria
# year                 2007
# population       33333216
# cont               Africa
# life_exp           72.301
# gdp_cap       6223.367465
# Name: 35, dtype: object

# %%
bricks_csv.loc[[35]]
# Out:
#     country  year  population    cont  life_exp      gdp_cap
# 35  Algeria  2007    33333216  Africa    72.301  6223.367465

# %%
bricks_csv.loc[[23, 35, 47]]
# Out:
#     country  year  population    cont  life_exp      gdp_cap
# 23  Albania  2007     3600523  Europe    76.423  5937.029526
# 35  Algeria  2007    33333216  Africa    72.301  6223.367465
# 47   Angola  2007    12420476  Africa    42.731  4797.231267

# %%
bricks_csv.loc[[23, 35, 47], ["country" , "population", "year", "cont"]]
# Out:
#     country  population  year    cont
# 23  Albania     3600523  2007  Europe
# 35  Algeria    33333216  2007  Africa
# 47   Angola    12420476  2007  Africa

# %%
bricks_csv
# Out:
#                  country  year  population      cont  life_exp       gdp_cap
# 11           Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23               Albania  2007     3600523    Europe    76.423   5937.029526
# 35               Algeria  2007    33333216    Africa    72.301   6223.367465
# 47                Angola  2007    12420476    Africa    42.731   4797.231267
# 59             Argentina  2007    40301927  Americas    75.320  12779.379640
# ...                  ...   ...         ...       ...       ...           ...
# 1655             Vietnam  2007    85262356      Asia    74.249   2441.576404
# 1667  West Bank and Gaza  2007     4018332      Asia    73.422   3025.349798
# 1679         Yemen, Rep.  2007    22211743      Asia    62.698   2280.769906
# 1691              Zambia  2007    11746035    Africa    42.384   1271.211593
# 1703            Zimbabwe  2007    12311143    Africa    43.487    469.709298
#
# [142 rows x 6 columns]
